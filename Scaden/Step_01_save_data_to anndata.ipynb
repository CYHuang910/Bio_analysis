# %%
from tqdm import tqdm
import torch
import random
import numpy as np
import pandas as pd
import collections
import anndata
from anndata import read_h5ad
import scanpy as sc
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ###       Load input data from a h5ad file and divide into training and test set
# #####     原始scaden好像沒有特別切分
# #####     :param input_path: path to h5ad file
# #####     :param batch_size: batch size to use for training
# #####     :param datasets: a list of datasets to extract from the file
# #####     :return: Dataset object

# %%
#input_path = "./pbmc_data.h5ad"
#raw_input = read_h5ad(input_path)

# %%
#raw_input
#raw_input.obs
#raw_input.var
#raw_input.X
#collections.Counter(raw_input.obs['ds'])

# %% [markdown]
# ### Simulate RNA data from harmony 轉成 h5ad

# %%
exp = pd.read_csv("./0.input_data/0819_Simulate_RNA/0819_Simulate_RNA_after_harmony_filter.csv")
metadata = pd.read_csv("./0.input_data/0819_Simulate_RNA/0819-3.Simulate_RNA_after_harmony_filter_metadata.csv")
wall = pd.read_csv("./0.input_data/0819_Simulate_RNA/0819-1.Simulate_RNA_after_harmony_filter_wall_table.csv",
                   index_col=0)
exp = exp.drop(exp.columns[0],axis=1)

# %%
#gene = pd.read_csv("./0.input_data/0522_scRNA_25type_top1000_filter_genes.csv")
gene = pd.read_csv("./0.input_data/simulate_remain_cgl2_harmony_gene.csv")

# %%
print(exp.shape)
print(wall.shape)
# Out:
# (1971, 40000)
# (40000, 25)

# %%
symbol = list(gene['x'])
exp.index = symbol
#exp = exp.T

wall = wall.apply(lambda x: x/x.sum(), axis=1)

metadata.index = list(metadata['barcode'])
metadata = metadata['donor']
meta = pd.concat([wall, metadata], axis=1)

# %%
# log 2 transfromation
#genes_ID x sample
total_set = np.log2(exp+1)
total_set
# Out:
#            Simulate_RNA_after_scRNA_harmony_1  \
# SEMA3F                              10.702285
# HECW1                               10.701501
# CYP26B1                             10.702085
# ABCB5                               10.701604
# CALCR                               10.702875
# ...                                       ...
# LINC01144                           10.701499
# FAM95C                              10.701372
# LINC00032                           10.701627
# OR8B3                               10.701594
# HULC                                10.698270
#
#            Simulate_RNA_after_scRNA_harmony_2  \
# SEMA3F                              10.702177
# HECW1                               10.701515
# CYP26B1                             10.702341
# ABCB5                               10.701682
# CALCR                               10.702740
# ...                                       ...
# LINC01144                           10.701521
# FAM95C                              10.701360
# LINC00032                           10.701642
# OR8B3                               10.701646
# HULC                                10.698226
#
#            Simulate_RNA_after_scRNA_harmony_3  \
# SEMA3F                              10.700756
# HECW1                               10.701546
# CYP26B1                             10.701524
# ABCB5                               10.701713
# CALCR                               10.702441
# ...                                       ...
# LINC01144                           10.701557
# FAM95C                              10.701414
# LINC00032                           10.701609
# OR8B3                               10.701608
# HULC                                10.702576
#
#            Simulate_RNA_after_scRNA_harmony_4  \
# SEMA3F                              10.699747
# HECW1                               10.701515
# CYP26B1                             10.700948
# ABCB5                               10.701591
# CALCR                               10.702346
# ...                                       ...
# LINC01144                           10.701550
# FAM95C                              10.701394
# LINC00032                           10.701620
# OR8B3                               10.701656
# HULC                                10.701915
#
#            Simulate_RNA_after_scRNA_harmony_5  \
# SEMA3F                              10.701197
# HECW1                               10.701506
# CYP26B1                             10.701186
# ABCB5                               10.701622
# CALCR                               10.702498
# ...                                       ...
# LINC01144                           10.701597
# FAM95C                              10.701379
# LINC00032                           10.701609
# OR8B3                               10.701612
# HULC                                10.702910
#
#            Simulate_RNA_after_scRNA_harmony_6  \
# SEMA3F                              10.700347
# HECW1                               10.701508
# CYP26B1                             10.701287
# ABCB5                               10.701652
# CALCR                               10.702374
# ...                                       ...
# LINC01144                           10.701376
# FAM95C                              10.701315
# LINC00032                           10.701716
# OR8B3                               10.701615
# HULC                                10.700685
#
#            Simulate_RNA_after_scRNA_harmony_7  \
# SEMA3F                              10.700405
# HECW1                               10.701570
# CYP26B1                             10.701296
# ABCB5                               10.701642
# CALCR                               10.702449
# ...                                       ...
# LINC01144                           10.701597
# FAM95C                              10.701363
# LINC00032                           10.701764
# OR8B3                               10.701643
# HULC                                10.703397
#
#            Simulate_RNA_after_scRNA_harmony_8  \
# SEMA3F                              10.699038
# HECW1                               10.701468
# CYP26B1                             10.700755
# ABCB5                               10.701608
# CALCR                               10.702620
# ...                                       ...
# LINC01144                           10.701507
# FAM95C                              10.701304
# LINC00032                           10.701599
# OR8B3                               10.701646
# HULC                                10.702402
#
#            Simulate_RNA_after_scRNA_harmony_9  \
# SEMA3F                              10.701095
# HECW1                               10.701521
# CYP26B1                             10.701213
# ABCB5                               10.701632
# CALCR                               10.702423
# ...                                       ...
# LINC01144                           10.701464
# FAM95C                              10.701377
# LINC00032                           10.701663
# OR8B3                               10.701654
# HULC                                10.701871
#
#            Simulate_RNA_after_scRNA_harmony_10  ...  \
# SEMA3F                               10.700506  ...
# HECW1                                10.701522  ...
# CYP26B1                              10.701540  ...
# ABCB5                                10.701652  ...
# CALCR                                10.702648  ...
# ...                                        ...  ...
# LINC01144                            10.701677  ...
# FAM95C                               10.701351  ...
# LINC00032                            10.701607  ...
# OR8B3                                10.701574  ...
# HULC                                 10.701144  ...
#
#            Simulate_RNA_after_scRNA_harmony_39991  \
# SEMA3F                                  10.699904
# HECW1                                   10.701407
# CYP26B1                                 10.701259
# ABCB5                                   10.701484
# CALCR                                   10.702110
# ...                                           ...
# LINC01144                               10.700661
# FAM95C                                  10.701121
# LINC00032                               10.701377
# OR8B3                                   10.701554
# HULC                                    10.695972
#
#            Simulate_RNA_after_scRNA_harmony_39992  \
# SEMA3F                                  10.699497
# HECW1                                   10.701396
# CYP26B1                                 10.701119
# ABCB5                                   10.701494
# CALCR                                   10.702929
# ...                                           ...
# LINC01144                               10.700971
# FAM95C                                  10.701023
# LINC00032                               10.701370
# OR8B3                                   10.701566
# HULC                                    10.696630
#
#            Simulate_RNA_after_scRNA_harmony_39993  \
# SEMA3F                                  10.699836
# HECW1                                   10.701419
# CYP26B1                                 10.701042
# ABCB5                                   10.701478
# CALCR                                   10.702190
# ...                                           ...
# LINC01144                               10.700728
# FAM95C                                  10.701072
# LINC00032                               10.701314
# OR8B3                                   10.701568
# HULC                                    10.697575
#
#            Simulate_RNA_after_scRNA_harmony_39994  \
# SEMA3F                                  10.699419
# HECW1                                   10.701436
# CYP26B1                                 10.701327
# ABCB5                                   10.701458
# CALCR                                   10.702598
# ...                                           ...
# LINC01144                               10.700918
# FAM95C                                  10.701145
# LINC00032                               10.701367
# OR8B3                                   10.701557
# HULC                                    10.697680
#
#            Simulate_RNA_after_scRNA_harmony_39995  \
# SEMA3F                                  10.700599
# HECW1                                   10.701362
# CYP26B1                                 10.701213
# ABCB5                                   10.701481
# CALCR                                   10.701862
# ...                                           ...
# LINC01144                               10.700677
# FAM95C                                  10.701070
# LINC00032                               10.701336
# OR8B3                                   10.701538
# HULC                                    10.696146
#
#            Simulate_RNA_after_scRNA_harmony_39996  \
# SEMA3F                                  10.699738
# HECW1                                   10.701405
# CYP26B1                                 10.701610
# ABCB5                                   10.701491
# CALCR                                   10.702245
# ...                                           ...
# LINC01144                               10.700899
# FAM95C                                  10.701055
# LINC00032                               10.701379
# OR8B3                                   10.701559
# HULC                                    10.696856
#
#            Simulate_RNA_after_scRNA_harmony_39997  \
# SEMA3F                                  10.700006
# HECW1                                   10.701385
# CYP26B1                                 10.701187
# ABCB5                                   10.701489
# CALCR                                   10.702392
# ...                                           ...
# LINC01144                               10.700822
# FAM95C                                  10.701101
# LINC00032                               10.701300
# OR8B3                                   10.701533
# HULC                                    10.696796
#
#            Simulate_RNA_after_scRNA_harmony_39998  \
# SEMA3F                                  10.699460
# HECW1                                   10.701438
# CYP26B1                                 10.700979
# ABCB5                                   10.701462
# CALCR                                   10.702697
# ...                                           ...
# LINC01144                               10.700825
# FAM95C                                  10.701152
# LINC00032                               10.701507
# OR8B3                                   10.701570
# HULC                                    10.697177
#
#            Simulate_RNA_after_scRNA_harmony_39999  \
# SEMA3F                                  10.699853
# HECW1                                   10.701423
# CYP26B1                                 10.701222
# ABCB5                                   10.701432
# CALCR                                   10.702436
# ...                                           ...
# LINC01144                               10.700706
# FAM95C                                  10.701106
# LINC00032                               10.701333
# OR8B3                                   10.701564
# HULC                                    10.697130
#
#            Simulate_RNA_after_scRNA_harmony_40000
# SEMA3F                                  10.700357
# HECW1                                   10.701416
# CYP26B1                                 10.701198
# ABCB5                                   10.701474
# CALCR                                   10.702007
# ...                                           ...
# LINC01144                               10.700801
# FAM95C                                  10.701065
# LINC00032                               10.701421
# OR8B3                                   10.701575
# HULC                                    10.697359
#
# [1971 rows x 40000 columns]

# %%
# 對每個細胞進行 min max scaler
scaler = MinMaxScaler(feature_range=(0, 1))
total_set = scaler.fit_transform(total_set)
total_set = total_set.T
total_set.shape
# Out:
# (40000, 1971)

# %%
adata = sc.AnnData(X = total_set, obs = meta, dtype = 'float32')
adata
# Out:
# AnnData object with n_obs × n_vars = 40000 × 1971
#     obs: 'CD141+DC', 'CD4/CD8-C1-CCR7', 'CD4/CD8-C2-MKI67', 'CD8-C7-KLRD1', 'CD8-C9-SLC4A10', 'Central memory T cells', 'Circulating NK', 'Conventional dendritic cells(CD1C DC)', 'Cytotoxicity CD8T', 'DC-C4-LAMP3', 'Effector memory T cells', 'Exhausted CD8+ T (Tex) cells', 'ILCs', 'Liver-resident NK (lrNK) cell', 'Lymphoid-B', 'M-C4-GPX3', 'M1', 'Mast', 'Mono', 'Myeloid-derived suppressor cells', 'NK', 'TAM-like', 'Th0', 'Th1', 'Treg', 'donor'

# %%
adata.write('./0819_simulate_harmony_10p_400cell.h5ad')
# Out:
# ... storing 'donor' as categorical

# %%
print(adata.X)
# Out:
# [[0.40708616 0.41086468 0.4101966  ... 0.40673444 0.40753734 0.40669328]
#  [0.416816   0.42551008 0.41929892 ... 0.41529727 0.4166121  0.41578513]
#  [0.42765132 0.43434086 0.43002236 ... 0.42680675 0.42789    0.4270775 ]
#  ...
#  [0.3309121  0.32991502 0.33051074 ... 0.33116788 0.3315232  0.33089715]
#  [0.343845   0.3430046  0.34332058 ... 0.3441015  0.34457627 0.34384733]
#  [0.35368448 0.35309914 0.3532627  ... 0.35396788 0.35435963 0.3536556 ]]

# %%
collections.Counter(adata.obs['donor'])
# Out:
# Counter({'D20171109': 1600,
#          'D20171215': 1600,
#          'D20180108': 1600,
#          'D20180110': 1600,
#          'D20180116': 1600})

# %%
adata.obs
# Out:
#                                         CD141+DC  CD4/CD8-C1-CCR7  \
# Simulate_RNA_after_scRNA_harmony_1        0.0100           0.0425
# Simulate_RNA_after_scRNA_harmony_2        0.0100           0.0525
# Simulate_RNA_after_scRNA_harmony_3        0.0075           0.0500
# Simulate_RNA_after_scRNA_harmony_4        0.0075           0.0475
# Simulate_RNA_after_scRNA_harmony_5        0.0075           0.0500
# ...                                          ...              ...
# Simulate_RNA_after_scRNA_harmony_39996    0.0100           0.0675
# Simulate_RNA_after_scRNA_harmony_39997    0.0100           0.0650
# Simulate_RNA_after_scRNA_harmony_39998    0.0100           0.0650
# Simulate_RNA_after_scRNA_harmony_39999    0.0100           0.0675
# Simulate_RNA_after_scRNA_harmony_40000    0.0125           0.0675
#
#                                         CD4/CD8-C2-MKI67  CD8-C7-KLRD1  \
# Simulate_RNA_after_scRNA_harmony_1                0.0100        0.0500
# Simulate_RNA_after_scRNA_harmony_2                0.0075        0.0550
# Simulate_RNA_after_scRNA_harmony_3                0.0075        0.0500
# Simulate_RNA_after_scRNA_harmony_4                0.0100        0.0425
# Simulate_RNA_after_scRNA_harmony_5                0.0075        0.0475
# ...                                                  ...           ...
# Simulate_RNA_after_scRNA_harmony_39996            0.0075        0.0400
# Simulate_RNA_after_scRNA_harmony_39997            0.0100        0.0400
# Simulate_RNA_after_scRNA_harmony_39998            0.0100        0.0425
# Simulate_RNA_after_scRNA_harmony_39999            0.0100        0.0475
# Simulate_RNA_after_scRNA_harmony_40000            0.0100        0.0450
#
#                                         CD8-C9-SLC4A10  \
# Simulate_RNA_after_scRNA_harmony_1              0.0200
# Simulate_RNA_after_scRNA_harmony_2              0.0175
# Simulate_RNA_after_scRNA_harmony_3              0.0175
# Simulate_RNA_after_scRNA_harmony_4              0.0175
# Simulate_RNA_after_scRNA_harmony_5              0.0200
# ...                                                ...
# Simulate_RNA_after_scRNA_harmony_39996          0.0225
# Simulate_RNA_after_scRNA_harmony_39997          0.0175
# Simulate_RNA_after_scRNA_harmony_39998          0.0200
# Simulate_RNA_after_scRNA_harmony_39999          0.0225
# Simulate_RNA_after_scRNA_harmony_40000          0.0225
#
#                                         Central memory T cells  \
# Simulate_RNA_after_scRNA_harmony_1                      0.1275
# Simulate_RNA_after_scRNA_harmony_2                      0.1100
# Simulate_RNA_after_scRNA_harmony_3                      0.1275
# Simulate_RNA_after_scRNA_harmony_4                      0.1175
# Simulate_RNA_after_scRNA_harmony_5                      0.1275
# ...                                                        ...
# Simulate_RNA_after_scRNA_harmony_39996                  0.1825
# Simulate_RNA_after_scRNA_harmony_39997                  0.1950
# Simulate_RNA_after_scRNA_harmony_39998                  0.1825
# Simulate_RNA_after_scRNA_harmony_39999                  0.1650
# Simulate_RNA_after_scRNA_harmony_40000                  0.1650
#
#                                         Circulating NK  \
# Simulate_RNA_after_scRNA_harmony_1              0.0300
# Simulate_RNA_after_scRNA_harmony_2              0.0275
# Simulate_RNA_after_scRNA_harmony_3              0.0275
# Simulate_RNA_after_scRNA_harmony_4              0.0325
# Simulate_RNA_after_scRNA_harmony_5              0.0325
# ...                                                ...
# Simulate_RNA_after_scRNA_harmony_39996          0.0325
# Simulate_RNA_after_scRNA_harmony_39997          0.0325
# Simulate_RNA_after_scRNA_harmony_39998          0.0300
# Simulate_RNA_after_scRNA_harmony_39999          0.0325
# Simulate_RNA_after_scRNA_harmony_40000          0.0300
#
#                                         Conventional dendritic cells(CD1C DC)  \
# Simulate_RNA_after_scRNA_harmony_1                                     0.0575
# Simulate_RNA_after_scRNA_harmony_2                                     0.0575
# Simulate_RNA_after_scRNA_harmony_3                                     0.0575
# Simulate_RNA_after_scRNA_harmony_4                                     0.0575
# Simulate_RNA_after_scRNA_harmony_5                                     0.0575
# ...                                                                       ...
# Simulate_RNA_after_scRNA_harmony_39996                                 0.0225
# Simulate_RNA_after_scRNA_harmony_39997                                 0.0200
# Simulate_RNA_after_scRNA_harmony_39998                                 0.0225
# Simulate_RNA_after_scRNA_harmony_39999                                 0.0200
# Simulate_RNA_after_scRNA_harmony_40000                                 0.0200
#
#                                         Cytotoxicity CD8T  DC-C4-LAMP3  ...  \
# Simulate_RNA_after_scRNA_harmony_1                 0.0625       0.0100  ...
# Simulate_RNA_after_scRNA_harmony_2                 0.0700       0.0100  ...
# Simulate_RNA_after_scRNA_harmony_3                 0.0650       0.0100  ...
# Simulate_RNA_after_scRNA_harmony_4                 0.0625       0.0100  ...
# Simulate_RNA_after_scRNA_harmony_5                 0.0725       0.0075  ...
# ...                                                   ...          ...  ...
# Simulate_RNA_after_scRNA_harmony_39996             0.0500       0.0100  ...
# Simulate_RNA_after_scRNA_harmony_39997             0.0525       0.0075  ...
# Simulate_RNA_after_scRNA_harmony_39998             0.0525       0.0100  ...
# Simulate_RNA_after_scRNA_harmony_39999             0.0450       0.0100  ...
# Simulate_RNA_after_scRNA_harmony_40000             0.0500       0.0125  ...
#
#                                             M1    Mast    Mono  \
# Simulate_RNA_after_scRNA_harmony_1      0.0275  0.0150  0.0175
# Simulate_RNA_after_scRNA_harmony_2      0.0250  0.0150  0.0175
# Simulate_RNA_after_scRNA_harmony_3      0.0275  0.0150  0.0175
# Simulate_RNA_after_scRNA_harmony_4      0.0275  0.0175  0.0200
# Simulate_RNA_after_scRNA_harmony_5      0.0275  0.0150  0.0175
# ...                                        ...     ...     ...
# Simulate_RNA_after_scRNA_harmony_39996  0.0275  0.0100  0.0200
# Simulate_RNA_after_scRNA_harmony_39997  0.0300  0.0100  0.0150
# Simulate_RNA_after_scRNA_harmony_39998  0.0300  0.0125  0.0175
# Simulate_RNA_after_scRNA_harmony_39999  0.0300  0.0100  0.0175
# Simulate_RNA_after_scRNA_harmony_40000  0.0300  0.0100  0.0200
#
#                                         Myeloid-derived suppressor cells  \
# Simulate_RNA_after_scRNA_harmony_1                                0.1175
# Simulate_RNA_after_scRNA_harmony_2                                0.1175
# Simulate_RNA_after_scRNA_harmony_3                                0.1000
# Simulate_RNA_after_scRNA_harmony_4                                0.1075
# Simulate_RNA_after_scRNA_harmony_5                                0.1025
# ...                                                                  ...
# Simulate_RNA_after_scRNA_harmony_39996                            0.0325
# Simulate_RNA_after_scRNA_harmony_39997                            0.0300
# Simulate_RNA_after_scRNA_harmony_39998                            0.0325
# Simulate_RNA_after_scRNA_harmony_39999                            0.0275
# Simulate_RNA_after_scRNA_harmony_40000                            0.0300
#
#                                             NK  TAM-like     Th0     Th1  \
# Simulate_RNA_after_scRNA_harmony_1      0.0250    0.0525  0.0325  0.0100
# Simulate_RNA_after_scRNA_harmony_2      0.0250    0.0550  0.0275  0.0100
# Simulate_RNA_after_scRNA_harmony_3      0.0300    0.0550  0.0325  0.0075
# Simulate_RNA_after_scRNA_harmony_4      0.0300    0.0575  0.0325  0.0075
# Simulate_RNA_after_scRNA_harmony_5      0.0325    0.0525  0.0275  0.0075
# ...                                        ...       ...     ...     ...
# Simulate_RNA_after_scRNA_harmony_39996  0.0175    0.0200  0.0300  0.0200
# Simulate_RNA_after_scRNA_harmony_39997  0.0225    0.0200  0.0325  0.0175
# Simulate_RNA_after_scRNA_harmony_39998  0.0200    0.0175  0.0325  0.0200
# Simulate_RNA_after_scRNA_harmony_39999  0.0225    0.0200  0.0275  0.0225
# Simulate_RNA_after_scRNA_harmony_40000  0.0225    0.0200  0.0325  0.0175
#
#                                           Treg      donor
# Simulate_RNA_after_scRNA_harmony_1      0.0100  D20171109
# Simulate_RNA_after_scRNA_harmony_2      0.0075  D20171109
# Simulate_RNA_after_scRNA_harmony_3      0.0100  D20171109
# Simulate_RNA_after_scRNA_harmony_4      0.0075  D20171109
# Simulate_RNA_after_scRNA_harmony_5      0.0075  D20171109
# ...                                        ...        ...
# Simulate_RNA_after_scRNA_harmony_39996  0.0725  D20180116
# Simulate_RNA_after_scRNA_harmony_39997  0.0675  D20180116
# Simulate_RNA_after_scRNA_harmony_39998  0.0725  D20180116
# Simulate_RNA_after_scRNA_harmony_39999  0.0775  D20180116
# Simulate_RNA_after_scRNA_harmony_40000  0.0675  D20180116
#
# [40000 rows x 26 columns]

# %% [markdown]
# ### Simulate RNA data from SCT 轉成 h5ad

# %%
exp = pd.read_csv("./0.input_data/0819_Simulate_RNA/0819_Simulate_RNA_after_SCT_filter.csv")
metadata = pd.read_csv("./0.input_data/0819_Simulate_RNA/0819-3.Simulate_RNA_after_SCT_filter_metadata.csv")
wall = pd.read_csv("./0.input_data/0819_Simulate_RNA/0819-1.Simulate_RNA_after_SCT_filter_wall_table.csv",
                   index_col=0)
exp = exp.drop(exp.columns[0],axis=1)

# %%
#gene = pd.read_csv("./0.input_data/0622_scRNA_after_SCT_filter_genes_cv_20to200.csv")
gene = pd.read_csv("./0.input_data/simulate_remain_cgl2_sct_gene.csv")

# %%
print(exp.shape)
print(wall.shape)
# Out:
# (2870, 40000)
# (40000, 25)

# %%
symbol = list(gene['x'])
exp.index = symbol
#exp = exp.T

wall = wall.apply(lambda x: x/x.sum(), axis=1)

metadata.index = list(metadata['barcode'])
metadata = metadata['donor']
meta = pd.concat([wall, metadata], axis=1)

# %%
# log 2 transfromation
#genes_ID x sample
total_set = np.log2(exp+1)
total_set
# Out:
#            Simulate_RNA_after_scRNA_SCT_1  Simulate_RNA_after_scRNA_SCT_2  \
# TSPAN6                           0.000000                        0.000000
# RAD52                            0.000000                        0.000000
# AOC1                             0.000000                        0.759707
# ALS2                             0.000000                        0.000000
# TFPI                             0.000000                        0.759707
# ...                                   ...                             ...
# LINC00891                        0.000000                        0.000000
# EXOC3L2                          0.000000                        0.000000
# LINC01226                        1.254772                        0.000000
# HULC                             0.000000                        0.000000
# RALY-AS1                         0.000000                        0.000000
#
#            Simulate_RNA_after_scRNA_SCT_3  Simulate_RNA_after_scRNA_SCT_4  \
# TSPAN6                           0.000000                        0.000000
# RAD52                            0.000000                        0.000000
# AOC1                             0.000000                        0.000000
# ALS2                             0.000000                        0.000000
# TFPI                             0.000000                        0.000000
# ...                                   ...                             ...
# LINC00891                        0.000000                        0.000000
# EXOC3L2                          0.000000                        0.000000
# LINC01226                        0.759707                        1.254772
# HULC                             0.000000                        0.000000
# RALY-AS1                         0.000000                        0.759707
#
#            Simulate_RNA_after_scRNA_SCT_5  Simulate_RNA_after_scRNA_SCT_6  \
# TSPAN6                           0.000000                             0.0
# RAD52                            0.000000                             0.0
# AOC1                             0.000000                             0.0
# ALS2                             0.000000                             0.0
# TFPI                             0.759707                             0.0
# ...                                   ...                             ...
# LINC00891                        0.000000                             0.0
# EXOC3L2                          0.000000                             0.0
# LINC01226                        0.000000                             0.0
# HULC                             0.000000                             0.0
# RALY-AS1                         0.000000                             0.0
#
#            Simulate_RNA_after_scRNA_SCT_7  Simulate_RNA_after_scRNA_SCT_8  \
# TSPAN6                                0.0                        0.000000
# RAD52                                 0.0                        0.000000
# AOC1                                  0.0                        0.000000
# ALS2                                  0.0                        0.000000
# TFPI                                  0.0                        0.759707
# ...                                   ...                             ...
# LINC00891                             0.0                        0.000000
# EXOC3L2                               0.0                        0.000000
# LINC01226                             0.0                        0.000000
# HULC                                  0.0                        0.000000
# RALY-AS1                              0.0                        0.000000
#
#            Simulate_RNA_after_scRNA_SCT_9  Simulate_RNA_after_scRNA_SCT_10  \
# TSPAN6                           0.000000                              0.0
# RAD52                            0.000000                              0.0
# AOC1                             0.000000                              0.0
# ALS2                             0.000000                              0.0
# TFPI                             0.000000                              0.0
# ...                                   ...                              ...
# LINC00891                        0.000000                              0.0
# EXOC3L2                          0.000000                              0.0
# LINC01226                        0.759707                              0.0
# HULC                             0.000000                              0.0
# RALY-AS1                         0.000000                              0.0
#
#            ...  Simulate_RNA_after_scRNA_SCT_39991  \
# TSPAN6     ...                            0.000000
# RAD52      ...                            0.000000
# AOC1       ...                            0.000000
# ALS2       ...                            0.000000
# TFPI       ...                            0.759707
# ...        ...                                 ...
# LINC00891  ...                            0.000000
# EXOC3L2    ...                            0.000000
# LINC01226  ...                            0.000000
# HULC       ...                            0.000000
# RALY-AS1   ...                            0.000000
#
#            Simulate_RNA_after_scRNA_SCT_39992  \
# TSPAN6                               0.000000
# RAD52                                0.000000
# AOC1                                 0.000000
# ALS2                                 0.000000
# TFPI                                 0.759707
# ...                                       ...
# LINC00891                            0.000000
# EXOC3L2                              0.000000
# LINC01226                            0.000000
# HULC                                 0.000000
# RALY-AS1                             0.000000
#
#            Simulate_RNA_after_scRNA_SCT_39993  \
# TSPAN6                                    0.0
# RAD52                                     0.0
# AOC1                                      0.0
# ALS2                                      0.0
# TFPI                                      0.0
# ...                                       ...
# LINC00891                                 0.0
# EXOC3L2                                   0.0
# LINC01226                                 0.0
# HULC                                      0.0
# RALY-AS1                                  0.0
#
#            Simulate_RNA_after_scRNA_SCT_39994  \
# TSPAN6                                    0.0
# RAD52                                     0.0
# AOC1                                      0.0
# ALS2                                      0.0
# TFPI                                      0.0
# ...                                       ...
# LINC00891                                 0.0
# EXOC3L2                                   0.0
# LINC01226                                 0.0
# HULC                                      0.0
# RALY-AS1                                  0.0
#
#            Simulate_RNA_after_scRNA_SCT_39995  \
# TSPAN6                               0.000000
# RAD52                                0.000000
# AOC1                                 0.000000
# ALS2                                 0.000000
# TFPI                                 0.759707
# ...                                       ...
# LINC00891                            0.000000
# EXOC3L2                              0.000000
# LINC01226                            0.000000
# HULC                                 0.000000
# RALY-AS1                             0.000000
#
#            Simulate_RNA_after_scRNA_SCT_39996  \
# TSPAN6                               0.000000
# RAD52                                0.000000
# AOC1                                 0.000000
# ALS2                                 0.000000
# TFPI                                 0.759707
# ...                                       ...
# LINC00891                            0.000000
# EXOC3L2                              0.000000
# LINC01226                            0.000000
# HULC                                 0.000000
# RALY-AS1                             0.000000
#
#            Simulate_RNA_after_scRNA_SCT_39997  \
# TSPAN6                               0.000000
# RAD52                                0.000000
# AOC1                                 0.000000
# ALS2                                 0.000000
# TFPI                                 0.759707
# ...                                       ...
# LINC00891                            0.000000
# EXOC3L2                              0.000000
# LINC01226                            0.000000
# HULC                                 0.000000
# RALY-AS1                             0.000000
#
#            Simulate_RNA_after_scRNA_SCT_39998  \
# TSPAN6                               0.000000
# RAD52                                0.000000
# AOC1                                 0.000000
# ALS2                                 0.000000
# TFPI                                 0.759707
# ...                                       ...
# LINC00891                            0.000000
# EXOC3L2                              0.000000
# LINC01226                            0.000000
# HULC                                 0.000000
# RALY-AS1                             0.759707
#
#            Simulate_RNA_after_scRNA_SCT_39999  \
# TSPAN6                                    0.0
# RAD52                                     0.0
# AOC1                                      0.0
# ALS2                                      0.0
# TFPI                                      0.0
# ...                                       ...
# LINC00891                                 0.0
# EXOC3L2                                   0.0
# LINC01226                                 0.0
# HULC                                      0.0
# RALY-AS1                                  0.0
#
#            Simulate_RNA_after_scRNA_SCT_40000
# TSPAN6                               0.000000
# RAD52                                0.000000
# AOC1                                 0.000000
# ALS2                                 0.000000
# TFPI                                 0.759707
# ...                                       ...
# LINC00891                            0.000000
# EXOC3L2                              0.000000
# LINC01226                            0.759707
# HULC                                 0.000000
# RALY-AS1                             0.000000
#
# [2870 rows x 40000 columns]

# %%
# 對每個細胞進行 min max scaler
scaler = MinMaxScaler(feature_range=(0, 1))
total_set = scaler.fit_transform(total_set)
total_set = total_set.T
total_set.shape
# Out:
# (40000, 2870)

# %%
adata = sc.AnnData(X = total_set, obs = meta, dtype = 'float32')
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 40000 × 2870
#     obs: 'CD141+DC', 'CD4/CD8-C1-CCR7', 'CD4/CD8-C2-MKI67', 'CD8-C7-KLRD1', 'CD8-C9-SLC4A10', 'Central memory T cells', 'Circulating NK', 'Conventional dendritic cells(CD1C DC)', 'Cytotoxicity CD8T', 'DC-C4-LAMP3', 'Effector memory T cells', 'Exhausted CD8+ T (Tex) cells', 'ILCs', 'Liver-resident NK (lrNK) cell', 'Lymphoid-B', 'M-C4-GPX3', 'M1', 'Mast', 'Mono', 'Myeloid-derived suppressor cells', 'NK', 'TAM-like', 'Th0', 'Th1', 'Treg', 'donor'

# %%
adata.write('./0819_simulate_SCT_cv20to200_10p_400cell.h5ad')
# Out:
# ... storing 'donor' as categorical

# %%
collections.Counter(adata.obs['donor'])
# Out:
# Counter({'D20171109': 8000,
#          'D20171215': 8000,
#          'D20180108': 8000,
#          'D20180110': 8000,
#          'D20180116': 8000})

# %%
adata.obs
# Out:
#                                     CD141+DC  CD4/CD8-C1-CCR7  \
# Simulate_RNA_after_scRNA_SCT_1        0.0100           0.0475
# Simulate_RNA_after_scRNA_SCT_2        0.0075           0.0450
# Simulate_RNA_after_scRNA_SCT_3        0.0075           0.0475
# Simulate_RNA_after_scRNA_SCT_4        0.0100           0.0475
# Simulate_RNA_after_scRNA_SCT_5        0.0100           0.0475
# ...                                      ...              ...
# Simulate_RNA_after_scRNA_SCT_39996    0.0100           0.0700
# Simulate_RNA_after_scRNA_SCT_39997    0.0100           0.0775
# Simulate_RNA_after_scRNA_SCT_39998    0.0100           0.0725
# Simulate_RNA_after_scRNA_SCT_39999    0.0100           0.0675
# Simulate_RNA_after_scRNA_SCT_40000    0.0100           0.0725
#
#                                     CD4/CD8-C2-MKI67  CD8-C7-KLRD1  \
# Simulate_RNA_after_scRNA_SCT_1                0.0075        0.0500
# Simulate_RNA_after_scRNA_SCT_2                0.0075        0.0450
# Simulate_RNA_after_scRNA_SCT_3                0.0075        0.0525
# Simulate_RNA_after_scRNA_SCT_4                0.0075        0.0450
# Simulate_RNA_after_scRNA_SCT_5                0.0075        0.0475
# ...                                              ...           ...
# Simulate_RNA_after_scRNA_SCT_39996            0.0100        0.0400
# Simulate_RNA_after_scRNA_SCT_39997            0.0100        0.0375
# Simulate_RNA_after_scRNA_SCT_39998            0.0100        0.0450
# Simulate_RNA_after_scRNA_SCT_39999            0.0100        0.0400
# Simulate_RNA_after_scRNA_SCT_40000            0.0100        0.0375
#
#                                     CD8-C9-SLC4A10  Central memory T cells  \
# Simulate_RNA_after_scRNA_SCT_1              0.0200                  0.1250
# Simulate_RNA_after_scRNA_SCT_2              0.0175                  0.1100
# Simulate_RNA_after_scRNA_SCT_3              0.0200                  0.1250
# Simulate_RNA_after_scRNA_SCT_4              0.0200                  0.1175
# Simulate_RNA_after_scRNA_SCT_5              0.0175                  0.1125
# ...                                            ...                     ...
# Simulate_RNA_after_scRNA_SCT_39996          0.0225                  0.1725
# Simulate_RNA_after_scRNA_SCT_39997          0.0200                  0.1775
# Simulate_RNA_after_scRNA_SCT_39998          0.0200                  0.1850
# Simulate_RNA_after_scRNA_SCT_39999          0.0200                  0.1825
# Simulate_RNA_after_scRNA_SCT_40000          0.0200                  0.1700
#
#                                     Circulating NK  \
# Simulate_RNA_after_scRNA_SCT_1              0.0275
# Simulate_RNA_after_scRNA_SCT_2              0.0275
# Simulate_RNA_after_scRNA_SCT_3              0.0300
# Simulate_RNA_after_scRNA_SCT_4              0.0275
# Simulate_RNA_after_scRNA_SCT_5              0.0300
# ...                                            ...
# Simulate_RNA_after_scRNA_SCT_39996          0.0350
# Simulate_RNA_after_scRNA_SCT_39997          0.0275
# Simulate_RNA_after_scRNA_SCT_39998          0.0275
# Simulate_RNA_after_scRNA_SCT_39999          0.0325
# Simulate_RNA_after_scRNA_SCT_40000          0.0325
#
#                                     Conventional dendritic cells(CD1C DC)  \
# Simulate_RNA_after_scRNA_SCT_1                                     0.0575
# Simulate_RNA_after_scRNA_SCT_2                                     0.0625
# Simulate_RNA_after_scRNA_SCT_3                                     0.0575
# Simulate_RNA_after_scRNA_SCT_4                                     0.0625
# Simulate_RNA_after_scRNA_SCT_5                                     0.0600
# ...                                                                   ...
# Simulate_RNA_after_scRNA_SCT_39996                                 0.0200
# Simulate_RNA_after_scRNA_SCT_39997                                 0.0200
# Simulate_RNA_after_scRNA_SCT_39998                                 0.0225
# Simulate_RNA_after_scRNA_SCT_39999                                 0.0175
# Simulate_RNA_after_scRNA_SCT_40000                                 0.0200
#
#                                     Cytotoxicity CD8T  DC-C4-LAMP3  ...  \
# Simulate_RNA_after_scRNA_SCT_1                 0.0625       0.0075  ...
# Simulate_RNA_after_scRNA_SCT_2                 0.0650       0.0100  ...
# Simulate_RNA_after_scRNA_SCT_3                 0.0725       0.0075  ...
# Simulate_RNA_after_scRNA_SCT_4                 0.0725       0.0075  ...
# Simulate_RNA_after_scRNA_SCT_5                 0.0750       0.0100  ...
# ...                                               ...          ...  ...
# Simulate_RNA_after_scRNA_SCT_39996             0.0475       0.0125  ...
# Simulate_RNA_after_scRNA_SCT_39997             0.0550       0.0100  ...
# Simulate_RNA_after_scRNA_SCT_39998             0.0475       0.0100  ...
# Simulate_RNA_after_scRNA_SCT_39999             0.0475       0.0100  ...
# Simulate_RNA_after_scRNA_SCT_40000             0.0475       0.0100  ...
#
#                                         M1    Mast    Mono  \
# Simulate_RNA_after_scRNA_SCT_1      0.0300  0.0175  0.0175
# Simulate_RNA_after_scRNA_SCT_2      0.0300  0.0175  0.0175
# Simulate_RNA_after_scRNA_SCT_3      0.0250  0.0175  0.0175
# Simulate_RNA_after_scRNA_SCT_4      0.0300  0.0175  0.0175
# Simulate_RNA_after_scRNA_SCT_5      0.0275  0.0200  0.0200
# ...                                    ...     ...     ...
# Simulate_RNA_after_scRNA_SCT_39996  0.0275  0.0100  0.0175
# Simulate_RNA_after_scRNA_SCT_39997  0.0275  0.0100  0.0200
# Simulate_RNA_after_scRNA_SCT_39998  0.0275  0.0100  0.0200
# Simulate_RNA_after_scRNA_SCT_39999  0.0300  0.0100  0.0175
# Simulate_RNA_after_scRNA_SCT_40000  0.0275  0.0100  0.0200
#
#                                     Myeloid-derived suppressor cells      NK  \
# Simulate_RNA_after_scRNA_SCT_1                                0.1075  0.0275
# Simulate_RNA_after_scRNA_SCT_2                                0.0975  0.0325
# Simulate_RNA_after_scRNA_SCT_3                                0.1100  0.0275
# Simulate_RNA_after_scRNA_SCT_4                                0.1075  0.0325
# Simulate_RNA_after_scRNA_SCT_5                                0.0975  0.0300
# ...                                                              ...     ...
# Simulate_RNA_after_scRNA_SCT_39996                            0.0300  0.0200
# Simulate_RNA_after_scRNA_SCT_39997                            0.0325  0.0175
# Simulate_RNA_after_scRNA_SCT_39998                            0.0300  0.0200
# Simulate_RNA_after_scRNA_SCT_39999                            0.0325  0.0200
# Simulate_RNA_after_scRNA_SCT_40000                            0.0300  0.0200
#
#                                     TAM-like     Th0     Th1    Treg  \
# Simulate_RNA_after_scRNA_SCT_1        0.0550  0.0275  0.0075  0.0075
# Simulate_RNA_after_scRNA_SCT_2        0.0625  0.0275  0.0075  0.0075
# Simulate_RNA_after_scRNA_SCT_3        0.0600  0.0300  0.0050  0.0075
# Simulate_RNA_after_scRNA_SCT_4        0.0575  0.0300  0.0100  0.0075
# Simulate_RNA_after_scRNA_SCT_5        0.0625  0.0275  0.0075  0.0075
# ...                                      ...     ...     ...     ...
# Simulate_RNA_after_scRNA_SCT_39996    0.0250  0.0300  0.0200  0.0625
# Simulate_RNA_after_scRNA_SCT_39997    0.0175  0.0300  0.0200  0.0650
# Simulate_RNA_after_scRNA_SCT_39998    0.0200  0.0275  0.0200  0.0725
# Simulate_RNA_after_scRNA_SCT_39999    0.0200  0.0275  0.0200  0.0750
# Simulate_RNA_after_scRNA_SCT_40000    0.0200  0.0300  0.0200  0.0675
#
#                                         donor
# Simulate_RNA_after_scRNA_SCT_1      D20171109
# Simulate_RNA_after_scRNA_SCT_2      D20171109
# Simulate_RNA_after_scRNA_SCT_3      D20171109
# Simulate_RNA_after_scRNA_SCT_4      D20171109
# Simulate_RNA_after_scRNA_SCT_5      D20171109
# ...                                       ...
# Simulate_RNA_after_scRNA_SCT_39996  D20180116
# Simulate_RNA_after_scRNA_SCT_39997  D20180116
# Simulate_RNA_after_scRNA_SCT_39998  D20180116
# Simulate_RNA_after_scRNA_SCT_39999  D20180116
# Simulate_RNA_after_scRNA_SCT_40000  D20180116
#
# [40000 rows x 26 columns]
